# %% [markdown]
# GRÁFICA DE BATCH SIZE ÓPTIMO

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3):
    plt.figure(figsize=(10, 5))

    # Plotting error lines
    plt.plot(sample_sizes, error1, label='80 muestras', color='red', linestyle='-')
    plt.plot(sample_sizes, error2, label='60 muestras', color='orange', linestyle='--')
    #plt.plot(sample_sizes, error3, label='100 muestras', color='green', linestyle='-.')

    # Plotting time lines
    #plt.plot(sample_sizes, time1, label='Con física', color='blue', linestyle='-')
    #plt.plot(sample_sizes, time2, label='Sin física', color='cyan', linestyle='--')
    #plt.plot(sample_sizes, time3, label='Entrenamiento Combinado', color='purple', linestyle='-.')

    # Setting the x-axis and y-axis to logarithmic
    #plt.xscale('log')
    #plt.yscale('log')

    # Adding labels
    plt.xlabel('Batch size (n)')
    plt.ylabel('Error (e)')

    # Adding a legend to distinguish the lines
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
sample_sizes = np.array([2, 3, 4, 5, 6, 7, 8, 9, 10, 20, 30, 40, 64, 80])
error1 = np.array([0.025537, 0.020923, 0.025351, 0.024899, 0.023988, 0.025585, 0.025491, 0.030205, 0.032400, 0.051733, 0.069410, 0.093669, 0.0752, 0.208335])
error2 = np.array([0.030807, 0.027947, 0.025225, 0.032097, 0.030852, 0.032504, 0.031775, 0.041551, 0.054632, 0.090100, 0.178677, 0.138112, 0.291985, 0.291985])
error3 = np.array([0.021700, 0.020078, 0.020073, 0.020171, 0.020634, 0.019871, 0.020910, 0.021485, 0.024616])
time1 = np.array([91, 115, 165, 220, 272, 333, 775*4])
time2 = np.array([72, 71, 72, 73, 78, 78, 201])
time3 = np.array([177, 200, 256, 319, 370, 431, 859*4])

plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3)

# %% [markdown]
# BATCH SIZE ZOOM

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3):
    plt.figure(figsize=(10, 5))

    # Plotting error lines
    plt.plot(sample_sizes, error1, label='80 muestras', color='red', linestyle='-')
    plt.plot(sample_sizes, error2, label='60 muestras', color='orange', linestyle='--')
    plt.plot(sample_sizes, error3, label='100 muestras', color='green', linestyle='-.')

    # Plotting time lines
    #plt.plot(sample_sizes, time1, label='Con física', color='blue', linestyle='-')
    #plt.plot(sample_sizes, time2, label='Sin física', color='cyan', linestyle='--')
    #plt.plot(sample_sizes, time3, label='Entrenamiento Combinado', color='purple', linestyle='-.')

    # Setting the x-axis and y-axis to logarithmic
    #plt.xscale('log')
    #plt.yscale('log')

    # Adding labels
    plt.xlabel('Batch size (n)')
    plt.ylabel('Error (e)')

    # Adding a legend to distinguish the lines
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
sample_sizes = np.array([2, 3, 4, 5, 6, 7, 8, 9, 10])
error1 = np.array([0.025537, 0.020923, 0.025351, 0.024899, 0.023988, 0.025585, 0.025491, 0.030205, 0.032400])
error2 = np.array([0.030807, 0.027947, 0.025225, 0.032097, 0.030852, 0.032504, 0.031775, 0.041551, 0.054632])
error3 = np.array([0.021700, 0.020078, 0.020073, 0.020171, 0.020634, 0.019871, 0.020910, 0.021485, 0.024616])
time1 = np.array([91, 115, 165, 220, 272, 333, 775*4])
time2 = np.array([72, 71, 72, 73, 78, 78, 201])
time3 = np.array([177, 200, 256, 319, 370, 431, 859*4])

plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3)

# %% [markdown]
# PARAMETRO FISICA

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3):
    plt.figure(figsize=(10, 5))

    # Plotting error lines
    plt.plot(sample_sizes, error1, label='80 muestras', color='red', linestyle='-')
    plt.plot(sample_sizes, error2, label='60 muestras', color='orange', linestyle='--')
    plt.plot(sample_sizes, error3, label='100 muestras', color='green', linestyle='-.')

    # Plotting time lines
    #plt.plot(sample_sizes, time1, label='Con física', color='blue', linestyle='-')
    #plt.plot(sample_sizes, time2, label='Sin física', color='cyan', linestyle='--')
    #plt.plot(sample_sizes, time3, label='Entrenamiento Combinado', color='purple', linestyle='-.')

    # Setting the x-axis and y-axis to logarithmic
    #plt.xscale('log')
    #plt.yscale('log')

    # Adding labels
    plt.xlabel('Parameter (p)')
    plt.ylabel('Error (e)')

    # Adding a legend to distinguish the lines
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
sample_sizes = np.array([0.25, 0.5, 0.75, 1, 2, 3, 4, 5, 6])
error1 = np.array([0.016113, 0.016086, 0.012796, 0.013092, 0.013800, 0.016987, 0.023370, 0.026741, 0.034669])
error2 = np.array([0.019635, 0.019442, 0.016700, 0.016542, 0.015863, 0.023099, 0.023122, 0.030254, 0.036303])
error3 = np.array([0.006805, 0.006606, 0.007032, 0.006711, 0.009587, 0.012671, 0.019118, 0.023845, 0.031330])
time1 = np.array([91, 115, 165, 220, 272, 333, 775*4])
time2 = np.array([72, 71, 72, 73, 78, 78, 201])
time3 = np.array([177, 200, 256, 319, 370, 431, 859*4])

plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3)

# %% [markdown]
# GRAFICA DE ERROR VS SAMPLE SIZE CON BATCH SIZE DE 5

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3):
    plt.figure(figsize=(10, 5))

    # Plotting error lines
    plt.plot(sample_sizes, error1, label='Con física', color='red', linestyle='-')
    plt.plot(sample_sizes, error2, label='Sin física', color='orange', linestyle='--')
    #plt.plot(sample_sizes, error3, label='Entrenamiento Combinado', color='green', linestyle='-.')

    # Plotting time lines
    #plt.plot(sample_sizes, time1, label='Con física', color='blue', linestyle='-')
    #plt.plot(sample_sizes, time2, label='Sin física', color='cyan', linestyle='--')
    #plt.plot(sample_sizes, time3, label='Entrenamiento Combinado', color='purple', linestyle='-.')

    # Setting the x-axis and y-axis to logarithmic
    plt.xscale('log')
    #plt.yscale('log')

    # Adding labels
    plt.xlabel('Sample Size (n)')
    plt.ylabel('Error (e)')

    # Adding a legend to distinguish the lines
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
sample_sizes = np.array([10, 20, 40, 60, 80, 100, 1000])
error1 = np.array([0.346556, 0.350984, 0.098879, 0.031253, 0.024397, 0.019877, 0.014373])
error2 = np.array([0.339266, 0.329728, 0.223951, 0.025617, 0.014644, 0.008714, 0.001999])
error3 = np.array([0.3942, 0.3290, 0.2515, 0.2586, 0.0549, 0.0829, 0.00534])
time1 = np.array([91, 115, 165, 220, 272, 333, 775*4])
time2 = np.array([72, 71, 72, 73, 78, 78, 201])
time3 = np.array([177, 200, 256, 319, 370, 431, 859*4])

plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3)

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3):
    plt.figure(figsize=(10, 5))

    # Plotting error lines
    #plt.plot(sample_sizes, error1, label='Con física', color='red', linestyle='-')
    #plt.plot(sample_sizes, error2, label='Sin física', color='orange', linestyle='--')
    #plt.plot(sample_sizes, error3, label='Entrenamiento Combinado', color='green', linestyle='-.')

    # Plotting time lines
    plt.plot(sample_sizes, time1, label='Con física', color='blue', linestyle='-')
    plt.plot(sample_sizes, time2, label='Sin física', color='cyan', linestyle='--')
    #plt.plot(sample_sizes, time3, label='Entrenamiento Combinado', color='purple', linestyle='-.')

    # Setting the x-axis and y-axis to logarithmic
    plt.xscale('log')
    #plt.yscale('log')

    # Adding labels
    plt.xlabel('Sample Size (n)')
    plt.ylabel('Time (Minutes)')

    # Adding a legend to distinguish the lines
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
sample_sizes = np.array([10, 20, 40, 60, 80, 100, 1000])
error1 = np.array([0.346556, 0.350984, 0.098879, 0.031253, 0.024397, 0.019877, 0.014373])
error2 = np.array([0.339266, 0.329728, 0.223951, 0.025617, 0.014644, 0.008714, 0.001999])
error3 = np.array([0.3942, 0.3290, 0.2515, 0.2586, 0.0549, 0.0829, 0.00534])
time1 = np.array([4 + 10/60, 4 + 45/60, 6 + 3/60, 7 + 15/60, 8 + 8/60, 9 + 21/60, 62 + 27/60])
time2 = np.array([3 + 36/60, 3 + 43/60, 4 + 1/60, 4 + 22/60, 4 + 38/60, 4 + 52/60, 18 + 13/60])
time3 = np.array([177, 200, 256, 319, 370, 431, 859*4])

plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3)

# %% [markdown]
# ANTES DE OPTIMIZAR

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3):
    plt.figure(figsize=(10, 5))

    # Plotting error lines
    plt.plot(sample_sizes, error1, label='Con física', color='red', linestyle='-')
    plt.plot(sample_sizes, error2, label='Sin física', color='orange', linestyle='--')
    #plt.plot(sample_sizes, error3, label='Entrenamiento Combinado', color='green', linestyle='-.')

    # Plotting time lines
    #plt.plot(sample_sizes, time1, label='Con física', color='blue', linestyle='-')
    #plt.plot(sample_sizes, time2, label='Sin física', color='cyan', linestyle='--')
    #plt.plot(sample_sizes, time3, label='Entrenamiento Combinado', color='purple', linestyle='-.')

    # Setting the x-axis and y-axis to logarithmic
    plt.xscale('log')
    #plt.yscale('log')

    # Adding labels
    plt.xlabel('Sample Size (n)')
    plt.ylabel('Error (e)')

    # Adding a legend to distinguish the lines
    plt.legend()

    # Show the plot
    plt.show()

# Example usage:
sample_sizes = np.array([10, 20, 40, 60, 80, 100, 1000])
error1 = np.array([0.4004, 0.3407, 0.2924, 0.2993, 0.0752, 0.0653, 0.005683])
error2 = np.array([0.4023, 0.3399, 0.3024, 0.3049, 0.0977, 0.1049, 0.00134])
error3 = np.array([0.3942, 0.3290, 0.2515, 0.2586, 0.0549, 0.0829, 0.00534])
time1 = np.array([91, 115, 165, 220, 272, 333, 775*4])
time2 = np.array([72, 71, 72, 73, 78, 78, 201])
time3 = np.array([177, 200, 256, 319, 370, 431, 859*4])

plot_sample_error_time(sample_sizes, error1, error2, error3, time1, time2, time3)
